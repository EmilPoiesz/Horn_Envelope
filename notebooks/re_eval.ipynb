# %%
from re_eval_methods import *
from scipy.special import comb
from helper_functions import *
from Horn import *
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# c:\Users\sophi\Miniconda3\envs\MT\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# Define the binarizer and its lookup.

# %%
country_file = 'data/country_list_continents.csv'
occ_file = 'data/occupations_subset.csv'
binarizer = Binarizer(country_file, 5, occ_file)

lookup = get_lookup(binarizer)

# %% [markdown]
# This cell saves the background to file.

# %%
dim = sum(binarizer.lengths.values()) + 2
V = define_variables(dim)

background = {(~(V[0] & V[1])),
(~(V[0] & V[2])),
(~(V[0] & V[3])),
(~(V[0] & V[4])),
(~(V[1] & V[2])),
(~(V[1] & V[3])),
(~(V[1] & V[4])),
(~(V[2] & V[3])),
(~(V[2] & V[4])),
(~(V[3] & V[4])),
(~(V[5] & V[6])),
(~(V[5] & V[7])),
(~(V[5] & V[8])),
(~(V[5] & V[9])),
(~(V[5] & V[10])),
(~(V[5] & V[11])),
(~(V[5] & V[12])),
(~(V[5] & V[13])),
(~(V[6] & V[7])),
(~(V[6] & V[8])),
(~(V[6] & V[9])),
(~(V[6] & V[10])),
(~(V[6] & V[11])),
(~(V[6] & V[12])),
(~(V[6] & V[13])),
(~(V[7] & V[8])),
(~(V[7] & V[9])),
(~(V[7] & V[10])),
(~(V[7] & V[11])),
(~(V[7] & V[12])),
(~(V[7] & V[13])),
(~(V[8] & V[9])),
(~(V[8] & V[10])),
(~(V[8] & V[11])),
(~(V[8] & V[12])),
(~(V[8] & V[13])),
(~(V[9] & V[10])),
(~(V[9] & V[11])),
(~(V[9] & V[12])),
(~(V[9] & V[13])),
(~(V[10] & V[11])),
(~(V[10] & V[12])),
(~(V[10] & V[13])),
(~(V[11] & V[12])),
(~(V[11] & V[13])),
(~(V[12] & V[13])),
(~(V[14] & V[15])),
(~(V[14] & V[16])),
(~(V[14] & V[17])),
(~(V[14] & V[18])),
(~(V[14] & V[19])),
(~(V[14] & V[20])),
(~(V[14] & V[21])),
(~(V[15] & V[16])),
(~(V[15] & V[17])),
(~(V[15] & V[18])),
(~(V[15] & V[19])),
(~(V[15] & V[20])),
(~(V[15] & V[21])),
(~(V[16] & V[17])),
(~(V[16] & V[18])),
(~(V[16] & V[19])),
(~(V[16] & V[20])),
(~(V[16] & V[21])),
(~(V[17] & V[18])),
(~(V[17] & V[19])),
(~(V[17] & V[20])),
(~(V[17] & V[21])),
(~(V[18] & V[19])),
(~(V[18] & V[20])),
(~(V[18] & V[21])),
(~(V[19] & V[20])),
(~(V[19] & V[21])),
(~(V[20] & V[21])),
(~(V[22] & V[23])),
}

with open('data_new/background.txt', 'wb') as f:
    pickle.dump(background, f)

# %% [markdown]
# # Single evaluation
#
# In this section, one can evaluate a single experimental result by converting the rules and print them out. A single experimental result means, all runs of one experiment setup (10 for the lower EQ nubmers).
#
# First, all rules from the file are loaded and converted into lists / dictionaries and concatenated into a list of all rules over all experiments.

# %%
""" Set the parameters for the desired experiment """

e = 1  # defines the number of experiments per setup
lm = 'roberta-base'
eq = 5000

# %%
experiments = range(1,e+1)
background = load_background()
all_negations = []
all_implications = []
for ex in experiments:
    h = load_rules(lm, eq, ex)
    all_rules = get_all_rules(h, background)
    (rules, negations, implications) = make_rule_lists(all_rules)
    all_negations = [*all_negations, *negations]
    all_implications = [*all_implications, *implications]

# %% [markdown]
# Count the rules over all experiments and print them out. (This includes **all** implications).

# %%
negations_count = count_lists(all_negations)
implications_count = count_lists(all_implications)
print_all_counted_rules(negations_count, implications_count, lookup)
# Out:
# 0.100  :  not (Eurasia & dancer & female & between 1951 and 1970 )
# 0.100  :  not (before 1875 & nurse & male & Europe )
# 0.100  :  not (dancer & female & between 1951 and 1970 & South America )
# 0.100  :  not (nurse & male & Africa )
# 0.100  :  not (dancer & male & Africa )
# 0.100  :  not (Oceania & dancer & male )
# 0.100  :  not (nurse & male & after 1970 & Asia )
# 0.100  :  not (dancer & female & between 1951 and 1970 & Asia )
# 0.100  :  not (Oceania & singer & female )
# 0.100  :  not (Americas & dancer & male & between 1951 and 1970 )
# 0.100  :  not (between 1875 and 1925 & Americas & dancer & male )
# 0.100  :  not (between 1875 and 1925 & nurse & male & Europe )
# 0.100  :  not (Eurasia & nurse & male & after 1970 )
# 0.100  :  not (between 1875 and 1925 & nurse & male & North America )
# 0.100  :  not (between 1875 and 1925 & dancer & male & South America )
# 0.100  :  not (before 1875 & Eurasia & dancer & male )
# 0.100  :  not (Americas & singer & female )
# 0.100  :  not (nurse & between 1925 and 1951 & female & Europe )
# 0.100  :  not (singer & female & after 1970 )
# 0.100  :  not (Eurasia & nurse & male & between 1951 and 1970 )
# 0.100  :  not (between 1875 and 1925 & Eurasia & nurse & male )
# 0.100  :  not (before 1875 & singer & female )
# 0.100  :  not (before 1875 & Americas & dancer & female )
# 0.100  :  not (before 1875 & dancer & female & South America )
# 0.100  :  not (singer & female & between 1951 and 1970 )
# 0.100  :  not (dancer & female & after 1970 & South America )
# 0.100  :  not (boxer & female )
# 0.100  :  not (between 1875 and 1925 & Eurasia & dancer & male )
# 0.100  :  not (Eurasia & nurse & between 1925 and 1951 & female )
# 0.100  :  not (Eurasia & dancer & female & after 1970 )
# 0.100  :  not (violinist & female )
# 0.100  :  not (dancer & between 1925 and 1951 & female & South America )
# 0.100  :  not (Australia & dancer & male )
# 0.100  :  not (industrialist & female )
# 0.100  :  not (between 1875 and 1925 & nurse & male & Asia )
# 0.100  :  not (between 1875 and 1925 & dancer & male & Asia )
# 0.100  :  not (nurse & male & South America )
# 0.100  :  not (Americas & dancer & female & after 1970 )
# 0.100  :  not (Eurasia & dancer & between 1925 and 1951 & male )
# 0.100  :  not (between 1875 and 1925 & dancer & male & North America )
# 0.100  :  not (between 1875 and 1925 & singer & female )
# 0.100  :  not (dancer & female & after 1970 & Asia )
# 0.100  :  not (Australia & nurse & male )
# 0.100  :  not (footballer & female )
# 0.100  :  not (fashion_designer & male )
# 0.100  :  not (nurse & female & after 1970 & Europe )
# 0.100  :  not (between 1925 and 1951 & singer & female )
# 0.100  :  not (Americas & nurse & male )
# 0.100  :  not (nurse & male & between 1951 and 1970 & Asia )
# 0.100  :  not (Americas & dancer & between 1925 and 1951 & male )
# 0.100  :  not (before 1875 & Eurasia & nurse & female )
# 0.100  :  not (nurse & female & between 1951 and 1970 & Europe )
# 0.100  :  not (dancer & male & Europe )
# 0.100  :  not (Oceania & nurse & between 1925 and 1951 & female )
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> Americas
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> South America
# 0.100  :  Americas & nurse & male  ---> Africa
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> dancer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> Americas
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> Australia
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> between 1951 and 1970
# 0.100  :  Eurasia & nurse & male & after 1970  ---> dancer
# 0.100  :  Eurasia & nurse & male & after 1970  ---> Australia
# 0.100  :  Australia & nurse & male  ---> dancer
# 0.100  :  industrialist & female  ---> Europe
# 0.100  :  Oceania & singer & female  ---> Australia
# 0.100  :  nurse & male & South America  ---> Oceania
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> industrialist
# 0.100  :  dancer & male & Africa  ---> South America
# 0.100  :  dancer & male & Europe  ---> Eurasia
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> female
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> North America
# 0.100  :  footballer & female  ---> male
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> Americas
# 0.100  :  before 1875 & nurse & male & Europe  ---> violinist
# 0.100  :  dancer & female & after 1970 & Asia  ---> fashion_designer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> Africa
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> North America
# 0.100  :  singer & female & between 1951 and 1970  ---> Europe
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> fashion_designer
# 0.100  :  footballer & female  ---> South America
# 0.100  :  nurse & female & after 1970 & Europe  ---> singer
# 0.100  :  before 1875 & dancer & female & South America  ---> industrialist
# 0.100  :  dancer & male & Africa  ---> between 1925 and 1951
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> violinist
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> female
# 0.100  :  nurse & female & after 1970 & Europe  ---> Australia
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> between 1875 and 1925
# 0.100  :  Oceania & singer & female  ---> violinist
# 0.100  :  boxer & female  ---> between 1925 and 1951
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> South America
# 0.100  :  singer & female & between 1951 and 1970  ---> fashion_designer
# 0.100  :  dancer & female & after 1970 & Asia  ---> singer
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Americas
# 0.100  :  industrialist & female  ---> dancer
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> after 1970
# 0.100  :  between 1925 and 1951 & singer & female  ---> footballer
# 0.100  :  nurse & male & Africa  ---> South America
# 0.100  :  dancer & female & after 1970 & South America  ---> nurse
# 0.100  :  violinist & female  ---> male
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> singer
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Australia
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> singer
# 0.100  :  nurse & female & after 1970 & Europe  ---> Eurasia
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> fashion_designer
# 0.100  :  before 1875 & singer & female  ---> Australia
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> before 1875
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> footballer
# 0.100  :  fashion_designer & male  ---> Europe
# 0.100  :  violinist & female  ---> South America
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> South America
# 0.100  :  Oceania & dancer & male  ---> Australia
# 0.100  :  footballer & female  ---> between 1925 and 1951
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> footballer
# 0.100  :  between 1925 and 1951 & singer & female  ---> Oceania
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Oceania
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> boxer
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Eurasia
# 0.100  :  Eurasia & dancer & female & after 1970  ---> between 1951 and 1970
# 0.100  :  nurse & male & after 1970 & Asia  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> before 1875
# 0.100  :  before 1875 & nurse & male & Europe  ---> after 1970
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> dancer
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Australia
# 0.100  :  nurse & female & after 1970 & Europe  ---> violinist
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> North America
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> singer
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> North America
# 0.100  :  boxer & female  ---> North America
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Oceania
# 0.100  :  before 1875 & Americas & dancer & female  ---> nurse
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> after 1970
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> violinist
# 0.100  :  Oceania & dancer & male  ---> Eurasia
# 0.100  :  Oceania & singer & female  ---> after 1970
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> violinist
# 0.100  :  before 1875 & nurse & male & Europe  ---> Asia
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> between 1875 and 1925
# 0.100  :  nurse & male & South America  ---> Africa
# 0.100  :  singer & female & after 1970  ---> male
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> singer
# 0.100  :  singer & female & between 1951 and 1970  ---> industrialist
# 0.100  :  before 1875 & singer & female  ---> violinist
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Australia
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> Eurasia
# 0.100  :  between 1875 and 1925 & singer & female  ---> boxer
# 0.100  :  Americas & nurse & male  ---> singer
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> North America
# 0.100  :  dancer & female & after 1970 & South America  ---> Americas
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> Asia
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> South America
# 0.100  :  Eurasia & nurse & male & after 1970  ---> Asia
# 0.100  :  Americas & nurse & male  ---> Australia
# 0.100  :  Oceania & singer & female  ---> Asia
# 0.100  :  Oceania & dancer & male  ---> violinist
# 0.100  :  dancer & male & Europe  ---> South America
# 0.100  :  fashion_designer & male  ---> dancer
# 0.100  :  singer & female & after 1970  ---> South America
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> violinist
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> industrialist
# 0.100  :  female & after 1970 & North America  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> before 1875
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Eurasia
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> boxer
# 0.100  :  Americas & nurse & male  ---> Eurasia
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> boxer
# 0.100  :  fashion_designer & male  ---> industrialist
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Oceania
# 0.100  :  Eurasia & nurse & male & after 1970  ---> female
# 0.100  :  Australia & nurse & male  ---> female
# 0.100  :  Americas & dancer & female & after 1970  ---> Europe
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> Australia
# 0.100  :  Eurasia & nurse & male & after 1970  ---> between 1875 and 1925
# 0.100  :  dancer & male & Africa  ---> boxer
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> footballer
# 0.100  :  Australia & nurse & male  ---> between 1875 and 1925
# 0.100  :  Eurasia & dancer & female & after 1970  ---> footballer
# 0.100  :  nurse & male & after 1970 & Asia  ---> footballer
# 0.100  :  Eurasia & dancer & female & after 1970  ---> boxer
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> violinist
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> after 1970
# 0.100  :  before 1875 & nurse & male & Europe  ---> between 1925 and 1951
# 0.100  :  nurse & male & after 1970 & Asia  ---> boxer
# 0.100  :  Australia & dancer & male  ---> after 1970
# 0.100  :  nurse & female & after 1970 & Europe  ---> male
# 0.100  :  Americas & nurse & male  ---> violinist
# 0.100  :  nurse & female & after 1970 & Europe  ---> Asia
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> before 1875
# 0.100  :  before 1875 & singer & female  ---> after 1970
# 0.100  :  before 1875 & dancer & female & South America  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Asia
# 0.100  :  dancer & female & after 1970 & South America  ---> singer
# 0.100  :  Australia & dancer & male  ---> Asia
# 0.100  :  Oceania & dancer & male  ---> after 1970
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> North America
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Oceania
# 0.100  :  nurse & female & after 1970 & Europe  ---> South America
# 0.100  :  dancer & female & after 1970 & Asia  ---> South America
# 0.100  :  Americas & singer & female  ---> Europe
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> after 1970
# 0.100  :  Australia & nurse & male  ---> between 1951 and 1970
# 0.100  :  before 1875 & singer & female  ---> Asia
# 0.100  :  footballer & female  ---> boxer
# 0.100  :  between 1925 and 1951 & singer & female  ---> Africa
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Africa
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> nurse
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> South America
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> boxer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> violinist
# 0.100  :  Oceania & dancer & male  ---> Asia
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> South America
# 0.100  :  before 1875 & Americas & dancer & female  ---> fashion_designer
# 0.100  :  dancer & female & after 1970 & South America  ---> Eurasia
# 0.100  :  nurse & male & Africa  ---> boxer
# 0.100  :  industrialist & female  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Africa
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Asia
# 0.100  :  before 1875 & dancer & female & South America  ---> between 1951 and 1970
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> male
# 0.100  :  Australia & dancer & male  ---> female
# 0.100  :  before 1875 & nurse & male & Europe  ---> North America
# 0.100  :  Australia & dancer & male  ---> between 1875 and 1925
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> after 1970
# 0.100  :  nurse & female & after 1970 & Europe  ---> between 1925 and 1951
# 0.100  :  Americas & nurse & male  ---> after 1970
# 0.100  :  before 1875 & Americas & dancer & female  ---> singer
# 0.100  :  violinist & female  ---> boxer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> boxer
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> North America
# 0.100  :  Eurasia & nurse & male & after 1970  ---> North America
# 0.100  :  Australia & nurse & male  ---> North America
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> South America
# 0.100  :  Oceania & singer & female  ---> North America
# 0.100  :  Americas & dancer & female & after 1970  ---> industrialist
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> before 1875
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> between 1925 and 1951
# 0.100  :  nurse & male & South America  ---> Australia
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> between 1925 and 1951
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Asia
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> male
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> Americas
# 0.100  :  Americas & nurse & male  ---> Asia
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> female
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Oceania
# 0.100  :  Americas & singer & female  ---> dancer
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> footballer
# 0.100  :  industrialist & female  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> boxer
# 0.100  :  singer & female & between 1951 and 1970  ---> between 1875 and 1925
# 0.100  :  before 1875 & singer & female  ---> between 1925 and 1951
# 0.100  :  before 1875 & Americas & dancer & female  ---> Eurasia
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Americas
# 0.100  :  Oceania & dancer & male  ---> between 1925 and 1951
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> after 1970
# 0.100  :  Americas & nurse & male  ---> South America
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Africa
# 0.100  :  Americas & singer & female  ---> industrialist
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> nurse
# 0.100  :  boxer & female  ---> nurse
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> boxer
# 0.100  :  dancer & male & Europe  ---> boxer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> Asia
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> before 1875
# 0.100  :  nurse & male & South America  ---> violinist
# 0.100  :  Eurasia & nurse & male & after 1970  ---> before 1875
# 0.100  :  Australia & nurse & male  ---> before 1875
# 0.100  :  fashion_designer & male  ---> female
# 0.100  :  Oceania & singer & female  ---> before 1875
# 0.100  :  singer & female & after 1970  ---> boxer
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> fashion_designer
# 0.100  :  fashion_designer & male  ---> between 1875 and 1925
# 0.100  :  before 1875 & dancer & female & South America  ---> footballer
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> Europe
# 0.100  :  Australia & dancer & male  ---> North America
# 0.100  :  Eurasia & nurse & male & after 1970  ---> Oceania
# 0.100  :  Australia & nurse & male  ---> Oceania
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Africa
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> between 1925 and 1951
# 0.100  :  Americas & nurse & male  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> fashion_designer
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> singer
# 0.100  :  dancer & female & after 1970 & South America  ---> male
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> between 1951 and 1970
# 0.100  :  before 1875 & dancer & female & South America  ---> Oceania
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> singer
# 0.100  :  between 1925 and 1951 & singer & female  ---> Australia
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Australia
# 0.100  :  industrialist & female  ---> footballer
# 0.100  :  fashion_designer & male  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & singer & female  ---> Europe
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Americas
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Americas
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> between 1925 and 1951
# 0.100  :  boxer & female  ---> Americas
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Australia
# 0.100  :  nurse & male & South America  ---> after 1970
# 0.100  :  dancer & female & after 1970 & Asia  ---> boxer
# 0.100  :  Australia & dancer & male  ---> before 1875
# 0.100  :  industrialist & female  ---> Oceania
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> Europe
# 0.100  :  before 1875 & Americas & dancer & female  ---> male
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> boxer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> boxer
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> Europe
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Africa
# 0.100  :  nurse & male & South America  ---> Asia
# 0.100  :  singer & female & between 1951 and 1970  ---> footballer
# 0.100  :  fashion_designer & male  ---> North America
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Eurasia
# 0.100  :  dancer & male & Africa  ---> Europe
# 0.100  :  between 1925 and 1951 & singer & female  ---> violinist
# 0.100  :  dancer & female & after 1970 & South America  ---> between 1925 and 1951
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> violinist
# 0.100  :  Americas & dancer & female & after 1970  ---> between 1875 and 1925
# 0.100  :  Eurasia & dancer & female & after 1970  ---> Europe
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> industrialist
# 0.100  :  before 1875 & Americas & dancer & female  ---> South America
# 0.100  :  nurse & male & after 1970 & Asia  ---> Europe
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> before 1875
# 0.100  :  dancer & male & Africa  ---> fashion_designer
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> fashion_designer
# 0.100  :  boxer & female  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & singer & female  ---> dancer
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> violinist
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> footballer
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> boxer
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> boxer
# 0.100  :  singer & female & between 1951 and 1970  ---> Oceania
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> singer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> North America
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Australia
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> singer
# 0.100  :  boxer & female  ---> singer
# 0.100  :  fashion_designer & male  ---> footballer
# 0.100  :  footballer & female  ---> Europe
# 0.100  :  between 1875 and 1925 & singer & female  ---> industrialist
# 0.100  :  Americas & singer & female  ---> between 1875 and 1925
# 0.100  :  Americas & dancer & female & after 1970  ---> between 1951 and 1970
# 0.100  :  Oceania & singer & female  ---> nurse
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> Africa
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> dancer
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Europe
# 0.100  :  Eurasia & nurse & male & after 1970  ---> Africa
# 0.100  :  Australia & nurse & male  ---> Africa
# 0.100  :  footballer & female  ---> fashion_designer
# 0.100  :  fashion_designer & male  ---> before 1875
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Eurasia
# 0.100  :  nurse & male & Africa  ---> Europe
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Americas
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Australia
# 0.100  :  between 1925 and 1951 & singer & female  ---> after 1970
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Eurasia
# 0.100  :  fashion_designer & male  ---> Oceania
# 0.100  :  nurse & male & after 1970 & Asia  ---> dancer
# 0.100  :  boxer & female  ---> Eurasia
# 0.100  :  before 1875 & dancer & female & South America  ---> Africa
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> industrialist
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> male
# 0.100  :  violinist & female  ---> Europe
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> industrialist
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> violinist
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> Europe
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> after 1970
# 0.100  :  Americas & singer & female  ---> between 1951 and 1970
# 0.100  :  dancer & male & Africa  ---> industrialist
# 0.100  :  between 1925 and 1951 & singer & female  ---> Asia
# 0.100  :  Americas & dancer & female & after 1970  ---> North America
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Eurasia
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> fashion_designer
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> South America
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> after 1970
# 0.100  :  before 1875 & nurse & male & Europe  ---> Americas
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> Europe
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> South America
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> dancer
# 0.100  :  industrialist & female  ---> Africa
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> nurse
# 0.100  :  Australia & dancer & male  ---> nurse
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> violinist
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> Americas
# 0.100  :  Eurasia & nurse & male & after 1970  ---> Americas
# 0.100  :  Australia & dancer & male  ---> Africa
# 0.100  :  Oceania & singer & female  ---> Americas
# 0.100  :  nurse & male & South America  ---> North America
# 0.100  :  nurse & male & Africa  ---> dancer
# 0.100  :  before 1875 & singer & female  ---> nurse
# 0.100  :  dancer & female & after 1970 & South America  ---> boxer
# 0.100  :  footballer & female  ---> industrialist
# 0.100  :  Americas & dancer & female & after 1970  ---> footballer
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> Europe
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> singer
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Australia
# 0.100  :  Oceania & dancer & male  ---> nurse
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> industrialist
# 0.100  :  violinist & female  ---> dancer
# 0.100  :  singer & female & after 1970  ---> Europe
# 0.100  :  Americas & dancer & female & after 1970  ---> before 1875
# 0.100  :  before 1875 & nurse & male & Europe  ---> fashion_designer
# 0.100  :  nurse & male & Africa  ---> industrialist
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Africa
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> between 1875 and 1925
# 0.100  :  Americas & dancer & female & after 1970  ---> Oceania
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Eurasia
# 0.100  :  nurse & female & after 1970 & Europe  ---> Americas
# 0.100  :  violinist & female  ---> industrialist
# 0.100  :  before 1875 & nurse & male & Europe  ---> singer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> industrialist
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> between 1925 and 1951
# 0.100  :  Americas & singer & female  ---> footballer
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> male
# 0.100  :  boxer & female  ---> male
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> nurse
# 0.100  :  before 1875 & Americas & dancer & female  ---> boxer
# 0.100  :  nurse & male & South America  ---> before 1875
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> after 1970
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Americas
# 0.100  :  Australia & dancer & male  ---> Americas
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> singer
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> violinist
# 0.100  :  Eurasia & nurse & male & after 1970  ---> singer
# 0.100  :  Australia & nurse & male  ---> singer
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> South America
# 0.100  :  Americas & singer & female  ---> before 1875
# 0.100  :  fashion_designer & male  ---> Africa
# 0.100  :  boxer & female  ---> South America
# 0.100  :  before 1875 & singer & female  ---> Americas
# 0.100  :  Americas & singer & female  ---> Oceania
# 0.100  :  before 1875 & nurse & male & Europe  ---> Eurasia
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Asia
# 0.100  :  singer & female & after 1970  ---> dancer
# 0.100  :  Oceania & dancer & male  ---> Americas
# 0.100  :  dancer & female & after 1970 & Asia  ---> Europe
# 0.100  :  before 1875 & dancer & female & South America  ---> Australia
# 0.100  :  between 1925 and 1951 & singer & female  ---> North America
# 0.100  :  nurse & female & after 1970 & Europe  ---> fashion_designer
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> Eurasia
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Americas
# 0.100  :  Australia & nurse & male  ---> Eurasia
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> industrialist
# 0.100  :  Oceania & singer & female  ---> Eurasia
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> Europe
# 0.100  :  dancer & male & Europe  ---> industrialist
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> between 1875 and 1925
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> female
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> fashion_designer
# 0.100  :  singer & female & after 1970  ---> industrialist
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & singer & female  ---> between 1951 and 1970
# 0.100  :  dancer & male & Africa  ---> between 1875 and 1925
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> North America
# 0.100  :  Eurasia & nurse & male & after 1970  ---> violinist
# 0.100  :  Australia & nurse & male  ---> violinist
# 0.100  :  Eurasia & dancer & female & after 1970  ---> between 1875 and 1925
# 0.100  :  nurse & male & after 1970 & Asia  ---> female
# 0.100  :  before 1875 & singer & female  ---> fashion_designer
# 0.100  :  nurse & male & after 1970 & Asia  ---> between 1875 and 1925
# 0.100  :  industrialist & female  ---> Australia
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> singer
# 0.100  :  Oceania & dancer & male  ---> fashion_designer
# 0.100  :  Australia & dancer & male  ---> singer
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> Europe
# 0.100  :  before 1875 & dancer & female & South America  ---> violinist
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> between 1925 and 1951
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> between 1951 and 1970
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> boxer
# 0.100  :  between 1925 and 1951 & singer & female  ---> before 1875
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> between 1951 and 1970
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> male
# 0.100  :  Oceania & dancer & male  ---> singer
# 0.100  :  between 1875 and 1925 & singer & female  ---> North America
# 0.100  :  dancer & male & Africa  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> footballer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> dancer
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> boxer
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> female
# 0.100  :  Americas & dancer & female & after 1970  ---> Africa
# 0.100  :  Australia & dancer & male  ---> Eurasia
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> singer
# 0.100  :  nurse & female & after 1970 & Europe  ---> industrialist
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> South America
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> Americas
# 0.100  :  singer & female & between 1951 and 1970  ---> dancer
# 0.100  :  singer & female & between 1951 and 1970  ---> Australia
# 0.100  :  nurse & male & Africa  ---> female
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> fashion_designer
# 0.100  :  dancer & female & after 1970 & Asia  ---> industrialist
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> before 1875
# 0.100  :  nurse & male & Africa  ---> between 1875 and 1925
# 0.100  :  before 1875 & singer & female  ---> Eurasia
# 0.100  :  industrialist & female  ---> violinist
# 0.100  :  Americas & nurse & male  ---> fashion_designer
# 0.100  :  Australia & nurse & male  ---> after 1970
# 0.100  :  Australia & dancer & male  ---> violinist
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> industrialist
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> North America
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> Oceania
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> industrialist
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> North America
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> dancer
# 0.100  :  violinist & female  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> dancer
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Eurasia
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> female
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> Australia
# 0.100  :  between 1875 and 1925 & singer & female  ---> footballer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> between 1875 and 1925
# 0.100  :  footballer & female  ---> between 1951 and 1970
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> male
# 0.100  :  Australia & nurse & male  ---> Asia
# 0.100  :  Americas & singer & female  ---> Africa
# 0.100  :  Eurasia & dancer & female & after 1970  ---> North America
# 0.100  :  before 1875 & dancer & female & South America  ---> after 1970
# 0.100  :  Oceania & singer & female  ---> male
# 0.100  :  before 1875 & nurse & male & Europe  ---> South America
# 0.100  :  nurse & male & after 1970 & Asia  ---> North America
# 0.100  :  fashion_designer & male  ---> Australia
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & singer & female  ---> before 1875
# 0.100  :  nurse & male & Africa  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> female
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> fashion_designer
# 0.100  :  singer & female & between 1951 and 1970  ---> violinist
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> industrialist
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> South America
# 0.100  :  Eurasia & nurse & male & after 1970  ---> South America
# 0.100  :  Australia & nurse & male  ---> South America
# 0.100  :  Oceania & singer & female  ---> South America
# 0.100  :  before 1875 & dancer & female & South America  ---> Asia
# 0.100  :  between 1875 and 1925 & singer & female  ---> Oceania
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> footballer
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> footballer
# 0.100  :  violinist & female  ---> between 1951 and 1970
# 0.100  :  dancer & female & after 1970 & South America  ---> Europe
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> between 1951 and 1970
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> singer
# 0.100  :  dancer & male & Africa  ---> footballer
# 0.100  :  fashion_designer & male  ---> Eurasia
# 0.100  :  dancer & female & North America  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> female
# 0.100  :  industrialist & female  ---> after 1970
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> boxer
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> before 1875
# 0.100  :  dancer & male & Europe  ---> female
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> industrialist
# 0.100  :  dancer & female & after 1970 & South America  ---> fashion_designer
# 0.100  :  dancer & male & Europe  ---> between 1875 and 1925
# 0.100  :  Americas & nurse & male  ---> industrialist
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> Oceania
# 0.100  :  singer & female & after 1970  ---> between 1875 and 1925
# 0.100  :  nurse & male & Africa  ---> North America
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> between 1951 and 1970
# 0.100  :  nurse & male & South America  ---> Americas
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> Oceania
# 0.100  :  fashion_designer & male  ---> violinist
# 0.100  :  Eurasia & dancer & female & after 1970  ---> before 1875
# 0.100  :  industrialist & female  ---> Asia
# 0.100  :  nurse & male & after 1970 & Asia  ---> before 1875
# 0.100  :  Eurasia & nurse & male & after 1970  ---> between 1925 and 1951
# 0.100  :  Australia & nurse & male  ---> between 1925 and 1951
# 0.100  :  Oceania & singer & female  ---> between 1925 and 1951
# 0.100  :  dancer & male & Africa  ---> Oceania
# 0.100  :  Eurasia & dancer & female & after 1970  ---> Oceania
# 0.100  :  nurse & male & after 1970 & Asia  ---> Oceania
# 0.100  :  between 1925 and 1951 & singer & female  ---> nurse
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> nurse
# 0.100  :  before 1875 & singer & female  ---> male
# 0.100  :  singer & female & between 1951 and 1970  ---> after 1970
# 0.100  :  before 1875 & Americas & dancer & female  ---> Europe
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> between 1951 and 1970
# 0.100  :  before 1875 & dancer & female & South America  ---> between 1925 and 1951
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> footballer
# 0.100  :  Australia & dancer & male  ---> South America
# 0.100  :  dancer & male & Europe  ---> between 1951 and 1970
# 0.100  :  singer & female & after 1970  ---> between 1951 and 1970
# 0.100  :  nurse & male & Africa  ---> footballer
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> nurse
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> North America
# 0.100  :  Americas & dancer & female & after 1970  ---> Australia
# 0.100  :  before 1875 & singer & female  ---> South America
# 0.100  :  singer & female & between 1951 and 1970  ---> Asia
# 0.100  :  footballer & female  ---> Oceania
# 0.100  :  Oceania & dancer & male  ---> South America
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> after 1970
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> Africa
# 0.100  :  nurse & male & Africa  ---> before 1875
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Oceania
# 0.100  :  violinist & female  ---> footballer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> footballer
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> South America
# 0.100  :  dancer & female & after 1970 & South America  ---> industrialist
# 0.100  :  dancer & female & after 1970 & Asia  ---> between 1875 and 1925
# 0.100  :  industrialist & female  ---> between 1925 and 1951
# 0.100  :  fashion_designer & male  ---> after 1970
# 0.100  :  nurse & male & Africa  ---> Oceania
# 0.100  :  Americas & dancer & female & after 1970  ---> Eurasia
# 0.100  :  nurse & male & South America  ---> singer
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> Asia
# 0.100  :  Australia & dancer & male  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> female
# 0.100  :  singer & female & after 1970  ---> North America
# 0.100  :  Americas & singer & female  ---> Australia
# 0.100  :  before 1875 & dancer & female & South America  ---> North America
# 0.100  :  fashion_designer & male  ---> Asia
# 0.100  :  violinist & female  ---> Oceania
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> Oceania
# 0.100  :  between 1925 and 1951 & singer & female  ---> Americas
# 0.100  :  between 1875 and 1925 & singer & female  ---> Africa
# 0.100  :  Americas & dancer & female & after 1970  ---> violinist
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> before 1875
# 0.100  :  nurse & male & South America  ---> Eurasia
# 0.100  :  dancer & female & after 1970 & Asia  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> female
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> between 1875 and 1925
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> footballer
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Americas
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> Oceania
# 0.100  :  before 1875 & Americas & dancer & female  ---> industrialist
# 0.100  :  dancer & male & Europe  ---> footballer
# 0.100  :  before 1875 & nurse & male & Europe  ---> boxer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> male
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> between 1951 and 1970
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> Americas
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> Africa
# 0.100  :  singer & female & after 1970  ---> footballer
# 0.100  :  industrialist & female  ---> North America
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> Africa
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> before 1875
# 0.100  :  dancer & male & Europe  ---> before 1875
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> boxer
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> Europe
# 0.100  :  Americas & singer & female  ---> violinist
# 0.100  :  Eurasia & nurse & male & after 1970  ---> boxer
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> nurse
# 0.100  :  Oceania & singer & female  ---> boxer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> South America
# 0.100  :  between 1925 and 1951 & singer & female  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> Oceania
# 0.100  :  Eurasia & dancer & female & after 1970  ---> Africa
# 0.100  :  singer & female & after 1970  ---> before 1875
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> fashion_designer
# 0.100  :  nurse & male & after 1970 & Asia  ---> Africa
# 0.100  :  dancer & male & Europe  ---> Oceania
# 0.100  :  dancer & female & after 1970 & Asia  ---> North America
# 0.100  :  fashion_designer & male  ---> between 1925 and 1951
# 0.100  :  singer & female & after 1970  ---> Oceania
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> North America
# 0.100  :  singer & female & between 1951 and 1970  ---> North America
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> dancer
# 0.100  :  Americas & dancer & female & after 1970  ---> Asia
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> singer
# 0.100  :  nurse & female & after 1970 & Europe  ---> footballer
# 0.100  :  nurse & female & after 1970 & Europe  ---> boxer
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Africa
# 0.100  :  Americas & nurse & male  ---> between 1951 and 1970
# 0.100  :  industrialist & female  ---> before 1875
# 0.100  :  between 1925 and 1951 & female & North America  ---> fashion_designer
# 0.100  :  dancer & female & after 1970 & Asia  ---> footballer
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> singer
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> Australia
# 0.100  :  between 1925 and 1951 & singer & female  ---> Eurasia
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> North America
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> North America
# 0.100  :  Americas & singer & female  ---> after 1970
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> footballer
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> boxer
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> industrialist
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> footballer
# 0.100  :  Australia & dancer & male  ---> boxer
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> nurse
# 0.100  :  dancer & female & after 1970 & Asia  ---> before 1875
# 0.100  :  Eurasia & dancer & female & after 1970  ---> Americas
# 0.100  :  nurse & male & after 1970 & Asia  ---> Americas
# 0.100  :  dancer & female & after 1970 & South America  ---> between 1875 and 1925
# 0.100  :  before 1875 & singer & female  ---> boxer
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Europe
# 0.100  :  violinist & female  ---> Africa
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> industrialist
# 0.100  :  boxer & female  ---> Europe
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> Africa
# 0.100  :  dancer & female & after 1970 & Asia  ---> Oceania
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> before 1875
# 0.100  :  Americas & singer & female  ---> Asia
# 0.100  :  Oceania & dancer & male  ---> boxer
# 0.100  :  singer & female & between 1951 and 1970  ---> before 1875
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> Oceania
# 0.100  :  between 1875 and 1925 & singer & female  ---> Australia
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> Oceania
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> boxer
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> footballer
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> Africa
# 0.100  :  Americas & dancer & female & after 1970  ---> between 1925 and 1951
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> violinist
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> fashion_designer
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> before 1875
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> before 1875
# 0.100  :  dancer & female & after 1970 & South America  ---> between 1951 and 1970
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> Australia
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> footballer
# 0.100  :  before 1875 & Americas & dancer & female  ---> between 1875 and 1925
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> Oceania
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> Oceania
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> Africa
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> boxer
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> Australia
# 0.100  :  Americas & nurse & male  ---> footballer
# 0.100  :  dancer & male & Europe  ---> Africa
# 0.100  :  Americas & nurse & male  ---> boxer
# 0.100  :  nurse & male & South America  ---> between 1925 and 1951
# 0.100  :  dancer & male & Africa  ---> Australia
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> singer
# 0.100  :  Eurasia & dancer & female & after 1970  ---> singer
# 0.100  :  boxer & female  ---> dancer
# 0.100  :  singer & female & after 1970  ---> Africa
# 0.100  :  nurse & male & after 1970 & Asia  ---> singer
# 0.100  :  Eurasia & dancer & female & after 1970  ---> Australia
# 0.100  :  before 1875 & dancer & female & South America  ---> nurse
# 0.100  :  between 1875 and 1925 & singer & female  ---> violinist
# 0.100  :  nurse & male & after 1970 & Asia  ---> Australia
# 0.100  :  Americas & singer & female  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> industrialist
# 0.100  :  between 1925 and 1951 & singer & female  ---> male
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> industrialist
# 0.100  :  boxer & female  ---> industrialist
# 0.100  :  before 1875 & Americas & dancer & female  ---> between 1951 and 1970
# 0.100  :  before 1875 & female & North America  ---> fashion_designer
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> boxer
# 0.100  :  nurse & male & after 1970 & Asia  ---> Eurasia
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> violinist
# 0.100  :  footballer & female  ---> dancer
# 0.100  :  footballer & female  ---> Australia
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> violinist
# 0.100  :  between 1925 and 1951 & singer & female  ---> South America
# 0.100  :  industrialist & female  ---> nurse
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> fashion_designer
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Australia
# 0.100  :  dancer & male & Africa  ---> violinist
# ...
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> between 1875 and 1925
# 0.100  :  Oceania & singer & female  ---> between 1875 and 1925
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> boxer
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> between 1925 and 1951
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Oceania
# 0.100  :  boxer & female  ---> Oceania
# 0.100  :  dancer & male & Europe  ---> between 1925 and 1951
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> after 1970
# 0.100  :  Americas & dancer & female & after 1970  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> after 1970
# 0.100  :  violinist & female  ---> North America
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> North America
# 0.100  :  singer & female & after 1970  ---> between 1925 and 1951
# 0.100  :  industrialist & female  ---> South America
# 0.100  :  dancer & female & after 1970 & Asia  ---> male
# 0.100  :  before 1875 & nurse & male & Europe  ---> between 1951 and 1970
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> industrialist
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> Asia
# 0.100  :  nurse & male & South America  ---> Europe
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> Africa
# 0.100  :  dancer & female & after 1970 & South America  ---> Australia
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> Asia
# 0.100  :  footballer & female  ---> before 1875
# 0.100  :  Americas & dancer & female & after 1970  ---> singer
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> between 1951 and 1970
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> before 1875
# 0.100  :  singer & female & between 1951 and 1970  ---> male
# 0.100  :  Eurasia & nurse & male & after 1970  ---> between 1951 and 1970
# 0.100  :  Oceania & singer & female  ---> between 1951 and 1970
# 0.100  :  nurse & male & South America  ---> fashion_designer
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> nurse
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> after 1970
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> Africa
# 0.100  :  nurse & female & after 1970 & Europe  ---> between 1875 and 1925
# 0.100  :  Americas & singer & female  ---> fashion_designer
# 0.100  :  singer & female & between 1951 and 1970  ---> South America
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> female
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> Asia
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> female
# 0.100  :  dancer & male & Europe  ---> North America
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> between 1875 and 1925
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> footballer
# 0.100  :  violinist & female  ---> before 1875
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> before 1875
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> boxer
# 0.100  :  before 1875 & singer & female  ---> between 1875 and 1925
# 0.100  :  before 1875 & Americas & dancer & female  ---> Australia
# 0.100  :  dancer & female & after 1970 & Asia  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & singer & female  ---> nurse
# 0.100  :  dancer & female & after 1970 & South America  ---> violinist
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> South America
# 0.100  :  Oceania & dancer & male  ---> female
# 0.100  :  Oceania & dancer & male  ---> between 1875 and 1925
# 0.100  :  nurse & male & South America  ---> dancer
# 0.100  :  nurse & female & after 1970 & Europe  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & nurse & male & Europe  ---> between 1925 and 1951
# 0.100  :  fashion_designer & male  ---> South America
# 0.100  :  singer & female & between 1951 and 1970  ---> between 1925 and 1951
# 0.100  :  Americas & singer & female  ---> Eurasia
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> between 1951 and 1970
# 0.100  :  before 1875 & nurse & male & Europe  ---> footballer
# 0.100  :  Australia & dancer & male  ---> between 1951 and 1970
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> Americas
# 0.100  :  nurse & male & South America  ---> industrialist
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> nurse
# 0.100  :  between 1925 and 1951 & singer & female  ---> Europe
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Europe
# 0.100  :  before 1875 & singer & female  ---> between 1951 and 1970
# 0.100  :  Oceania & nurse & between 1925 and 1951 & female  ---> footballer
# 0.100  :  Eurasia & nurse & male & after 1970  ---> footballer
# 0.100  :  Australia & nurse & male  ---> footballer
# 0.100  :  dancer & male & Africa  ---> nurse
# 0.100  :  Oceania & singer & female  ---> footballer
# 0.100  :  Australia & nurse & male  ---> boxer
# 0.100  :  nurse & female & between 1951 and 1970 & Europe  ---> between 1925 and 1951
# 0.100  :  between 1875 and 1925 & Eurasia & nurse & male  ---> between 1925 and 1951
# 0.100  :  Oceania & dancer & male  ---> between 1951 and 1970
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Africa
# 0.100  :  Eurasia & dancer & female & after 1970  ---> nurse
# 0.100  :  boxer & female  ---> Africa
# 0.100  :  before 1875 & Americas & dancer & female  ---> violinist
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> between 1875 and 1925
# 0.100  :  nurse & female & after 1970 & Europe  ---> North America
# 0.100  :  Americas & nurse & male  ---> female
# 0.100  :  Americas & nurse & male  ---> between 1875 and 1925
# 0.100  :  before 1875 & nurse & male & Europe  ---> Oceania
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> Europe
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> between 1951 and 1970
# 0.100  :  before 1875 & dancer & female & South America  ---> boxer
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> North America
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> North America
# 0.100  :  between 1875 and 1925 & singer & female  ---> Americas
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> fashion_designer
# 0.100  :  before 1875 & singer & female  ---> North America
# 0.100  :  footballer & female  ---> nurse
# 0.100  :  dancer & female & after 1970 & South America  ---> Asia
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> Australia
# 0.100  :  footballer & female  ---> Africa
# 0.100  :  Oceania & dancer & male  ---> North America
# 0.100  :  Americas & dancer & female & after 1970  ---> male
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> between 1875 and 1925
# 0.100  :  between 1925 and 1951 & singer & female  ---> dancer
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> Americas
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> singer
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> Australia
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> Americas
# 0.100  :  industrialist & female  ---> boxer
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> footballer
# 0.100  :  Americas & dancer & female & after 1970  ---> South America
# 0.100  :  nurse & female & after 1970 & Europe  ---> before 1875
# 0.100  :  Australia & dancer & male  ---> footballer
# 0.100  :  dancer & male & Africa  ---> Americas
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> Eurasia
# 0.100  :  before 1875 & Americas & dancer & female  ---> after 1970
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> Europe
# 0.100  :  between 1875 and 1925 & singer & female  ---> fashion_designer
# 0.100  :  nurse & female & after 1970 & Europe  ---> Oceania
# 0.100  :  violinist & female  ---> nurse
# 0.100  :  before 1875 & singer & female  ---> footballer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> nurse
# 0.100  :  between 1925 and 1951 & singer & female  ---> industrialist
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> before 1875
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> before 1875
# 0.100  :  Oceania & dancer & male  ---> footballer
# 0.100  :  Americas & singer & female  ---> male
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> North America
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> between 1951 and 1970
# 0.100  :  before 1875 & Americas & dancer & female  ---> Asia
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> violinist
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Oceania
# 0.100  :  Americas & nurse & male  ---> North America
# 0.100  :  Australia & dancer & male  ---> Oceania
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> footballer
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> industrialist
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> nurse
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> fashion_designer
# 0.100  :  Oceania & dancer & male  ---> before 1875
# 0.100  :  singer & female & between 1951 and 1970  ---> boxer
# 0.100  :  Americas & singer & female  ---> South America
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> Europe
# 0.100  :  before 1875 & singer & female  ---> Oceania
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> fashion_designer
# 0.100  :  Eurasia & dancer & female & between 1951 and 1970  ---> industrialist
# 0.100  :  footballer & female  ---> Americas
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> violinist
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Americas
# 0.100  :  Eurasia & dancer & female & after 1970  ---> fashion_designer
# 0.100  :  nurse & male & after 1970 & Asia  ---> fashion_designer
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> singer
# 0.100  :  between 1875 and 1925 & singer & female  ---> Eurasia
# 0.100  :  between 1875 and 1925 & nurse & male & North America  ---> Oceania
# 0.100  :  nurse & male & Africa  ---> Americas
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> nurse
# 0.100  :  before 1875 & Eurasia & dancer & male  ---> singer
# 0.100  :  dancer & male & Europe  ---> nurse
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> dancer
# 0.100  :  before 1875 & nurse & male & Europe  ---> Africa
# 0.100  :  nurse & male & South America  ---> female
# 0.100  :  dancer & male & Africa  ---> singer
# 0.100  :  nurse & male & South America  ---> between 1875 and 1925
# 0.100  :  singer & female & after 1970  ---> nurse
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Australia
# 0.100  :  boxer & female  ---> Australia
# 0.100  :  fashion_designer & male  ---> boxer
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> before 1875
# 0.100  :  violinist & female  ---> Americas
# 0.100  :  Americas & nurse & male  ---> before 1875
# 0.100  :  Oceania & singer & female  ---> Africa
# 0.100  :  before 1875 & Americas & dancer & female  ---> between 1925 and 1951
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> after 1970
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Oceania
# 0.100  :  Americas & nurse & male  ---> Oceania
# 0.100  :  dancer & female & after 1970 & South America  ---> North America
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> fashion_designer
# 0.100  :  dancer & male & Africa  ---> Eurasia
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> after 1970
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> footballer
# 0.100  :  nurse & male & Africa  ---> fashion_designer
# 0.100  :  dancer & female & between 1951 and 1970 & Asia  ---> Europe
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> after 1970
# 0.100  :  nurse & between 1925 and 1951 & female & Europe  ---> Asia
# 0.100  :  footballer & female  ---> singer
# 0.100  :  nurse & male & South America  ---> between 1951 and 1970
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> singer
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> Asia
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> violinist
# 0.100  :  Americas & dancer & male & between 1951 and 1970  ---> industrialist
# 0.100  :  boxer & female  ---> violinist
# 0.100  :  violinist & female  ---> fashion_designer
# 0.100  :  Eurasia & dancer & female & after 1970  ---> industrialist
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> Asia
# 0.100  :  nurse & male & Africa  ---> singer
# 0.100  :  nurse & male & after 1970 & Asia  ---> industrialist
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> Americas
# 0.100  :  before 1875 & Eurasia & nurse & female  ---> Oceania
# 0.100  :  nurse & female & after 1970 & Europe  ---> Africa
# 0.100  :  dancer & male & Europe  ---> Americas
# 0.100  :  dancer & female & after 1970 & Asia  ---> nurse
# 0.100  :  footballer & female  ---> Eurasia
# 0.100  :  singer & female & after 1970  ---> Americas
# 0.100  :  before 1875 & Americas & dancer & female  ---> North America
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> South America
# 0.100  :  violinist & female  ---> singer
# 0.100  :  nurse & male & between 1951 and 1970 & Asia  ---> Eurasia
# 0.100  :  between 1875 and 1925 & dancer & male & South America  ---> Africa
# 0.100  :  between 1875 and 1925 & Americas & dancer & male  ---> fashion_designer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> singer
# 0.100  :  Eurasia & nurse & male & between 1951 and 1970  ---> Africa
# 0.100  :  dancer & female & after 1970 & South America  ---> before 1875
# 0.100  :  Oceania & nurse & male  ---> between 1925 and 1951
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> female
# 0.100  :  between 1925 and 1951 & singer & female  ---> between 1875 and 1925
# 0.100  :  Australia & nurse & male  ---> Europe
# 0.100  :  Eurasia & dancer & between 1925 and 1951 & male  ---> between 1875 and 1925
# 0.100  :  footballer & female  ---> violinist
# 0.100  :  before 1875 & singer & female  ---> Africa
# 0.100  :  between 1875 and 1925 & singer & female  ---> male
# 0.100  :  Americas & dancer & female & after 1970  ---> boxer
# 0.100  :  Oceania & dancer & male  ---> Africa
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> fashion_designer
# 0.100  :  between 1875 and 1925 & dancer & male & Asia  ---> female
# 0.100  :  violinist & female  ---> Eurasia
# 0.100  :  between 1875 and 1925 & nurse & male & Asia  ---> after 1970
# 0.100  :  before 1875 & female & Asia  ---> fashion_designer
# 0.100  :  dancer & male & Europe  ---> fashion_designer
# 0.100  :  Americas & dancer & between 1925 and 1951 & male  ---> Eurasia
# 0.100  :  before 1875 & dancer & female & South America  ---> Europe
# 0.100  :  between 1875 and 1925 & singer & female  ---> South America
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> after 1970
# 0.100  :  singer & female & after 1970  ---> fashion_designer
# 0.100  :  boxer & female  ---> after 1970
# 0.100  :  between 1875 and 1925 & Eurasia & dancer & male  ---> between 1925 and 1951
# 0.100  :  nurse & male & South America  ---> footballer
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> male
# 0.100  :  between 1875 and 1925 & dancer & male & North America  ---> singer
# 0.100  :  between 1925 and 1951 & singer & female  ---> between 1951 and 1970
# 0.100  :  dancer & male & Europe  ---> singer
# 0.100  :  before 1875 & nurse & male & Europe  ---> Australia
# 0.100  :  Americas & singer & female  ---> boxer
# 0.100  :  dancer & female & after 1970 & Asia  ---> Americas
# 0.100  :  dancer & between 1925 and 1951 & female & South America  ---> Asia
# 0.100  :  boxer & female  ---> Asia
# 0.100  :  Eurasia & nurse & between 1925 and 1951 & female  ---> South America
# 0.100  :  dancer & female & between 1951 and 1970 & South America  ---> Africa

# %% [markdown]
# Do the same, but exclude implications that are derived from a negation.

# %%
relevant_implications = []
for rule in all_implications:
    if rule['body'] not in all_negations:
        relevant_implications.append(rule)
relevant_implications_count = count_lists(relevant_implications)
print_all_counted_rules(negations_count, relevant_implications_count, lookup)
# Out:
# 0.100  :  not (Eurasia & dancer & female & between 1951 and 1970 )
# 0.100  :  not (before 1875 & nurse & male & Europe )
# 0.100  :  not (dancer & female & between 1951 and 1970 & South America )
# 0.100  :  not (nurse & male & Africa )
# 0.100  :  not (dancer & male & Africa )
# 0.100  :  not (Oceania & dancer & male )
# 0.100  :  not (nurse & male & after 1970 & Asia )
# 0.100  :  not (dancer & female & between 1951 and 1970 & Asia )
# 0.100  :  not (Oceania & singer & female )
# 0.100  :  not (Americas & dancer & male & between 1951 and 1970 )
# 0.100  :  not (between 1875 and 1925 & Americas & dancer & male )
# 0.100  :  not (between 1875 and 1925 & nurse & male & Europe )
# 0.100  :  not (Eurasia & nurse & male & after 1970 )
# 0.100  :  not (between 1875 and 1925 & nurse & male & North America )
# 0.100  :  not (between 1875 and 1925 & dancer & male & South America )
# 0.100  :  not (before 1875 & Eurasia & dancer & male )
# 0.100  :  not (Americas & singer & female )
# 0.100  :  not (nurse & between 1925 and 1951 & female & Europe )
# 0.100  :  not (singer & female & after 1970 )
# 0.100  :  not (Eurasia & nurse & male & between 1951 and 1970 )
# 0.100  :  not (between 1875 and 1925 & Eurasia & nurse & male )
# 0.100  :  not (before 1875 & singer & female )
# 0.100  :  not (before 1875 & Americas & dancer & female )
# 0.100  :  not (before 1875 & dancer & female & South America )
# 0.100  :  not (singer & female & between 1951 and 1970 )
# 0.100  :  not (dancer & female & after 1970 & South America )
# 0.100  :  not (boxer & female )
# 0.100  :  not (between 1875 and 1925 & Eurasia & dancer & male )
# 0.100  :  not (Eurasia & nurse & between 1925 and 1951 & female )
# 0.100  :  not (Eurasia & dancer & female & after 1970 )
# 0.100  :  not (violinist & female )
# 0.100  :  not (dancer & between 1925 and 1951 & female & South America )
# 0.100  :  not (Australia & dancer & male )
# 0.100  :  not (industrialist & female )
# 0.100  :  not (between 1875 and 1925 & nurse & male & Asia )
# 0.100  :  not (between 1875 and 1925 & dancer & male & Asia )
# 0.100  :  not (nurse & male & South America )
# 0.100  :  not (Americas & dancer & female & after 1970 )
# 0.100  :  not (Eurasia & dancer & between 1925 and 1951 & male )
# 0.100  :  not (between 1875 and 1925 & dancer & male & North America )
# 0.100  :  not (between 1875 and 1925 & singer & female )
# 0.100  :  not (dancer & female & after 1970 & Asia )
# 0.100  :  not (Australia & nurse & male )
# 0.100  :  not (footballer & female )
# 0.100  :  not (fashion_designer & male )
# 0.100  :  not (nurse & female & after 1970 & Europe )
# 0.100  :  not (between 1925 and 1951 & singer & female )
# 0.100  :  not (Americas & nurse & male )
# 0.100  :  not (nurse & male & between 1951 and 1970 & Asia )
# 0.100  :  not (Americas & dancer & between 1925 and 1951 & male )
# 0.100  :  not (before 1875 & Eurasia & nurse & female )
# 0.100  :  not (nurse & female & between 1951 and 1970 & Europe )
# 0.100  :  not (dancer & male & Europe )
# 0.100  :  not (Oceania & nurse & between 1925 and 1951 & female )
# 0.100  :  female & after 1970 & North America  ---> fashion_designer
# 0.100  :  dancer & female & North America  ---> between 1875 and 1925
# 0.100  :  between 1925 and 1951 & female & North America  ---> fashion_designer
# 0.100  :  before 1875 & female & North America  ---> fashion_designer
# 0.100  :  between 1925 and 1951 & female & Asia  ---> fashion_designer
# 0.100  :  female & between 1951 and 1970 & North America  ---> fashion_designer
# 0.100  :  Oceania & nurse & male  ---> between 1925 and 1951
# 0.100  :  before 1875 & female & Asia  ---> fashion_designer

# %% [markdown]
# Write them formatted to a file

# %%
filename_string = 'data/rule_extraction_final/formatted/' + lm + '_' + str(eq) +'.txt'
filename_latex = 'data/rule_extraction_final/formatted/' + lm + '_' + str(eq) +'_latex.txt'
for rule, count in sorted(negations_count, key=lambda rule: rule[1], reverse=True):
    rule_string = negation_to_string(rule, lookup)
    with open(filename_string, 'a') as f:
        line = "{:.3f}  :  {rule}".format(count/10, rule=rule_string)
        #print(line)
        f.write(line + '\n')
    with open(filename_latex, 'a') as f:
        line = "{} & {rule} \\\\".format(count, rule=negation_to_latex(rule, lookup))
        f.write(line + '\n')

for rule, count in sorted(relevant_implications_count, key=lambda rule: rule[1], reverse=True):
    rule_string = implication_to_string(rule, lookup)
    with open(filename_string, 'a') as f:
        line = "{:.3f}  :  {rule}".format(count/10, rule=rule_string)
        #print(line)
        f.write(line + '\n')
    with open(filename_latex, 'a') as f:
        line = "{} & {rule} \\\\".format(count, rule=implication_to_latex(rule, lookup))
        f.write(line + '\n')

# %% [markdown]
# Special sorting for the terminated runs

# %%
filename_string = 'data/rule_extraction_final/formatted/' + lm + '_' + str(eq) +'.txt'
filename_latex = 'data/rule_extraction_final/formatted/' + lm + '_' + str(eq) +'_latex.txt'
for rule in sorted(all_negations, key=lambda rule : len(rule)):
    rule_string = negation_to_string(rule, lookup)
    with open(filename_latex, 'a') as f:
        line = "${rule} \\\\".format(rule=negation_to_latex(rule, lookup))
        f.write(line + '\n')

for rule in sorted(relevant_implications, key=lambda rule : len(rule['body'])):
    rule_string = implication_to_string(rule, lookup)
    with open(filename_latex, 'a') as f:
        line = "${rule} \\\\".format(rule=implication_to_latex(rule, lookup))
        f.write(line + '\n')

# %% [markdown]
# # Single Runtime evaluation
#
# Evaluates the runtime of a single experimental setup with its multiple runs (10 for up to 200 EQs).

# %%
""" Set the parameters for the desired experiment """

e = 1  # defines the number of experiments per setup
lm = 'roberta-base'
eq = 5000

# %%
experiments = range(1,e+1)
total_runtime = 0
df = pd.DataFrame(columns=['samples', 'runtime', 'iteration'])
for ex in experiments:
    data_dict = get_data_dict(lm, eq, ex)
    total_runtime = total_runtime + float(data_dict['data']['runtime'])
    sample_list = data_dict['data']['average_sample']
    sample_df = make_sample_df(sample_list, eq=0)
    df = pd.concat([df, sample_df])
total_runtime = total_runtime / len(experiments)
print("{lm} - {e} EQs:".format(lm=lm, e=e))
print("\truntime average: {r:.2f} sec = {r1:.2f} min = {r2:.2f} h".format(r=total_runtime, r1 = total_runtime/60, r2=total_runtime/60/60))
# Out:
# roberta-base - 1 EQs:
# 	runtime average: 216035.63 sec = 3600.59 min = 60.01 h

# %%
print(df)
# Out:
#      samples      runtime  iteration
# 0        2.0     1.578248        1.0
# 1        2.0     0.810781        2.0
# 2        1.0     3.376113        3.0
# 3        1.0     0.720147        4.0
# 4        1.0     0.453650        5.0
# ..       ...          ...        ...
# 444    208.0  1953.759390      445.0
# 445    395.0   463.507908      446.0
# 446    788.0  2473.664651      447.0
# 447    587.0  2349.417094      448.0
# 448   5416.0  4842.446442      449.0
#
# [449 rows x 3 columns]

# %% [markdown]
# Visualize the amount of samples per equivalence query and the average

# %%
sns.lineplot(data=df, x='iteration', y='samples')
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='samples'>

# %%
sns.catplot(data=df, x='iteration', y='samples', height=6, aspect=1.5, palette='colorblind')
sns.catplot(data=df.groupby('iteration', as_index=False)['samples'].mean(), x='iteration', y='samples', height=6, aspect=1.5)

# %% [markdown]
# And do a similar visualization for the average runtime at each equivalence query.

# %%
sns.lineplot(data=df, x='iteration', y='runtime')
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='runtime'>

# %%
sns.catplot(data=df, x='iteration', y='runtime', height=6, aspect=1.5)
sns.catplot(data=df.groupby('iteration', as_index=False)['runtime'].mean(), x='iteration', y='runtime', height=6, aspect=1.5)

# %% [markdown]
# # Runtime Evaluation All
#
# ## Evaluate per model

# %%
eqs = [50, 100, 150, 200]
models = ['roberta-base', 'roberta-large', 'bert-base-cased', 'bert-large-cased']
experiments = range(1,11)

# %%
runtimes_df = pd.DataFrame(columns=['lm', 'eq', 'runtime sec', 'runtime min', 'runtime h'])
frames = []
for lm in models:
    df = pd.DataFrame(columns=['samples', 'runtime', 'iteration', 'eq'])
    for eq in eqs:
        total_runtime = 0
        for ex in experiments:
            data_dict = get_data_dict(lm, eq, ex)
            total_runtime = total_runtime + float(data_dict['data']['runtime'])
            sample_list = data_dict['data']['average_sample']
            sample_df = make_sample_df(sample_list, eq=eq)
            df = pd.concat([df, sample_df], ignore_index=True)
        total_runtime = total_runtime / len(experiments)
        #print("{lm} - {e} EQs:".format(lm=lm, e=eq))
        #print("\truntime average: {r:.2f} sec = {r1:.2f} min = {r2:.2f} h".format(r=total_runtime, r1 = total_runtime/60, r2=total_runtime/60/60))
        runtime_arr = [[lm, eq, total_runtime, total_runtime / 60, total_runtime / 60 / 60]]
        runtimes_df = pd.concat([runtimes_df, pd.DataFrame(runtime_arr, columns=['lm', 'eq', 'runtime sec', 'runtime min', 'runtime h'])], ignore_index=True)
    frames.append(df)

# %%
print(runtimes_df[['lm','eq','runtime min']].sort_values(by='eq'))

# %% [markdown]
# ### Plot the average sample per iteration for all models

# %%
models = ['roBERTa-base', 'roBERTa-large', 'BERT-base', 'BERT-large']

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9))
fig.suptitle('Sample per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    data = df.groupby(['eq', 'iteration'], as_index=False)['samples'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[int(i/2), i%2], data=data, x='iteration', y='samples', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[int(i/2), i%2].set_title(lm)
    axes[int(i/2), i%2].set_ylim([0, 30])
    axes[int(i/2), i%2].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Plot the average runtime per iteration for all models

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9))
fig.suptitle('Runtime per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    data = df.groupby(['eq', 'iteration'], as_index=False)['runtime'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[int(i/2), i%2], data=data, x='iteration', y='runtime', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[int(i/2), i%2].set_title(lm)
    axes[int(i/2), i%2].set_ylim([0, 450])
    axes[int(i/2), i%2].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Analyse the runtime per sample

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 9))
fig.suptitle('Average Runtime per Sample per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    df['runtime per sample'] = df['runtime'] / df['samples']
    data = df.groupby(['eq', 'iteration'], as_index=False)['runtime per sample'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[int(i/2), i%2], data=data, x='iteration', y='runtime per sample', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[int(i/2), i%2].set_title(lm)
    axes[int(i/2), i%2].set_ylim([0, 170])
    axes[int(i/2), i%2].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Relate the runtime to the hypothesis size

# %%
models = ['roberta-base', 'roberta-large', 'bert-base-cased', 'bert-large-cased']
eqs = [50, 100, 150, 200]
#eqs = [200]
experiments = range(1,11)
background = load_background()
lookup = get_lookup(binarizer)

# %%
rule_df = pd.DataFrame(columns=['lm', 'eq', 'experiment', '#rules', '#relevant', 'runtime'])
for lm in models:
    for eq in eqs:
        for e in experiments:
            h = load_rules(lm, eq, e)
            all_rules = get_all_rules(h, background)
            (rules, negations, implications) = make_rule_lists(all_rules)
            relevant_implications = []
            for rule in all_implications:
                if rule['body'] not in negations:
                    relevant_implications.append(rule)
            data_dict = get_data_dict(lm, eq, e)
            runtime = float(data_dict['data']['runtime'])
            new_df = pd.DataFrame([[lm, eq, e, len(all_rules), len(relevant_implications) + len(negations), runtime]], columns=['lm', 'eq', 'experiment', '#rules', '#relevant', 'runtime'])
            rule_df = pd.concat([rule_df, new_df], ignore_index=True)

# %%
rule_df['runtime per rule'] = rule_df['runtime'] / rule_df['#rules']
#print(rule_df.groupby(['lm', 'eq'], as_index=False)['runtime per rule'].mean())
mean_df = rule_df.groupby(['lm', 'eq'], as_index=False)['runtime per rule'].mean()
mean_df['mean #rules'] = rule_df.groupby(['lm', 'eq'], as_index=False)['#rules'].mean()['#rules']
mean_df['mean #relevant'] = rule_df.groupby(['lm', 'eq'], as_index=False)['#relevant'].mean()['#relevant']
mean_df['mean runtime'] = rule_df.groupby(['lm', 'eq'], as_index=False)['runtime'].mean()['runtime']
print(mean_df)

# %%
sns.catplot(data=mean_df, x='eq', y='mean #rules', hue= 'lm')
sns.catplot(data=mean_df, x='eq', y='mean #relevant', hue= 'lm')
sns.catplot(data=mean_df, x='eq', y='runtime per rule', hue= 'lm')

# %% [markdown]
# # Runtime Evaluation roBERTa

# %%
eqs = [50, 100, 150, 200]
models = ['roberta-base', 'roberta-large']
experiments = range(1,11)

# %%
runtimes_df = pd.DataFrame(columns=['lm', 'eq', 'runtime sec', 'runtime min', 'runtime h'])
frames = []
for lm in models:
    df = pd.DataFrame(columns=['samples', 'runtime', 'iteration', 'eq'])
    for eq in eqs:
        total_runtime = 0
        for ex in experiments:
            data_dict = get_data_dict(lm, eq, ex)
            total_runtime = total_runtime + float(data_dict['data']['runtime'])
            sample_list = data_dict['data']['average_sample']
            sample_df = make_sample_df(sample_list, eq=eq)
            df = pd.concat([df, sample_df], ignore_index=True)
        total_runtime = total_runtime / len(experiments)
        #print("{lm} - {e} EQs:".format(lm=lm, e=eq))
        #print("\truntime average: {r:.2f} sec = {r1:.2f} min = {r2:.2f} h".format(r=total_runtime, r1 = total_runtime/60, r2=total_runtime/60/60))
        runtime_arr = [[lm, eq, total_runtime, total_runtime / 60, total_runtime / 60 / 60]]
        runtimes_df = pd.concat([runtimes_df, pd.DataFrame(runtime_arr, columns=['lm', 'eq', 'runtime sec', 'runtime min', 'runtime h'])], ignore_index=True)
    frames.append(df)

# %%
print(runtimes_df[['lm','eq','runtime min']].sort_values(by='eq'))
# Out:
#               lm   eq  runtime min
# 0   roberta-base   50    14.304320
# 4  roberta-large   50    16.812329
# 1   roberta-base  100    59.247497
# 5  roberta-large  100    60.671643
# 2   roberta-base  150   170.612575
# 6  roberta-large  150   161.509698
# 3   roberta-base  200   423.045764
# 7  roberta-large  200   361.568661

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Sample per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    data = df.groupby(['eq', 'iteration'], as_index=False)['samples'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[i], data=data, x='iteration', y='samples', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[i].set_title(lm)
    axes[i].set_ylim([0, 20])
    axes[i].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Runtime per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    data = df.groupby(['eq', 'iteration'], as_index=False)['runtime'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[i], data=data, x='iteration', y='runtime', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[i].set_title(lm)
    axes[i].set_ylim([0, 450])
    axes[i].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle('Average Runtime per Sample per Iteration for all Models')
for i, lm in enumerate(models):
    df = frames[i]
    df['runtime per sample'] = df['runtime'] / df['samples']
    data = df.groupby(['eq', 'iteration'], as_index=False)['runtime per sample'].mean()
    hue_order = [200, 150, 100, 50]
    sns.lineplot(ax=axes[i], data=data, x='iteration', y='runtime per sample', hue='eq', palette='colorblind', hue_order=hue_order)
    axes[i].set_title(lm)
    axes[i].set_ylim([0, 170])
    axes[i].legend().set_title('# EQ')
fig.tight_layout()
plt.show()

# %%
background = load_background()
lookup = get_lookup(binarizer)

# %%
rule_df = pd.DataFrame(columns=['lm', 'eq', 'experiment', '#rules', '#relevant', 'runtime'])
for lm in models:
    for eq in eqs:
        for e in experiments:
            h = load_rules(lm, eq, e)
            all_rules = get_all_rules(h, background)
            (rules, negations, implications) = make_rule_lists(all_rules)
            relevant_implications = []
            for rule in all_implications:
                if rule['body'] not in negations:
                    relevant_implications.append(rule)
            data_dict = get_data_dict(lm, eq, e)
            runtime = float(data_dict['data']['runtime'])
            new_df = pd.DataFrame([[lm, eq, e, len(all_rules), len(relevant_implications) + len(negations), runtime]], columns=['lm', 'eq', 'experiment', '#rules', '#relevant', 'runtime'])
            rule_df = pd.concat([rule_df, new_df], ignore_index=True)

# %%
rule_df['runtime per rule'] = rule_df['runtime'] / rule_df['#rules']
#print(rule_df.groupby(['lm', 'eq'], as_index=False)['runtime per rule'].mean())
mean_df = rule_df.groupby(['lm', 'eq'], as_index=False)['runtime per rule'].mean()
mean_df['mean #rules'] = rule_df.groupby(['lm', 'eq'], as_index=False)['#rules'].mean()['#rules']
mean_df['mean #relevant'] = rule_df.groupby(['lm', 'eq'], as_index=False)['#relevant'].mean()['#relevant']
mean_df['mean runtime'] = rule_df.groupby(['lm', 'eq'], as_index=False)['runtime'].mean()['runtime']
print(mean_df)
# Out:
#               lm   eq  runtime per rule  mean #rules  mean #relevant  \
# 0   roberta-base   50          6.769086        153.0           945.7
# 1   roberta-base  100         14.718842        248.0           665.4
# 2   roberta-base  150         23.615715        442.4           622.1
# 3   roberta-base  200         47.711851        536.1           600.4
# 4  roberta-large   50          6.354711        163.2           858.9
# 5  roberta-large  100         14.614358        252.1           704.4
# 6  roberta-large  150         33.017226        304.3           710.9
# 7  roberta-large  200         51.478340        426.2           716.5
#
#    mean runtime
# 0    858.259188
# 1   3554.849831
# 2  10236.754475
# 3  25382.745822
# 4   1008.739725
# 5   3640.298588
# 6   9690.581859
# 7  21694.119684

# %%
sns.catplot(data=mean_df, x='eq', y='mean #rules', hue= 'lm')
sns.catplot(data=mean_df, x='eq', y='mean #relevant', hue= 'lm')
sns.catplot(data=mean_df, x='eq', y='runtime per rule', hue= 'lm')

# %% [markdown]
# # Runtime Evaluation with Hypothesis Size

# %%
data = pd.read_csv('output.txt').to_numpy()
frame = pd.DataFrame(columns=['iteration', 'value', 'type'])
for row in data:
    new_rows = [[row[0], row[1], 'len_h'], [row[0], row[2], 'runtime']]
    new_df = pd.DataFrame(new_rows, columns= ['iteration', 'value', 'type'])
    frame = pd.concat([frame, new_df], ignore_index=True)
print(frame)
# Out:
#      iteration        value     type
# 0          5.0    75.000000    len_h
# 1          5.0     0.453650  runtime
# 2         10.0   143.000000    len_h
# 3         10.0     7.091560  runtime
# 4         15.0   144.000000    len_h
# ..         ...          ...      ...
# 173      435.0  1552.102194  runtime
# 174      440.0  1138.000000    len_h
# 175      440.0  1740.692678  runtime
# 176      445.0  1201.000000    len_h
# 177      445.0  1953.759390  runtime
#
# [178 rows x 3 columns]

# %%
data = pd.read_csv('output.txt')
data['runtime'] = (data['runtime'] - data['runtime'].mean())/ data['runtime'].std()
data['len_h'] = (data['len_h'] - data['len_h'].mean())/ data['len_h'].std()
data = data.to_numpy()
frame_norm = pd.DataFrame(columns=['iteration', 'value', 'type'])
for row in data:
    new_rows = [[row[0], row[1], 'len_h'], [row[0], row[2], 'runtime']]
    new_df = pd.DataFrame(new_rows, columns= ['iteration', 'value', 'type'])
    frame_norm = pd.concat([frame_norm, new_df], ignore_index=True)
print(frame_norm)
# Out:
#      iteration     value     type
# 0          5.0 -1.920621    len_h
# 1          5.0 -0.891741  runtime
# 2         10.0 -1.675939    len_h
# 3         10.0 -0.878787  runtime
# 4         15.0 -1.672341    len_h
# ..         ...       ...      ...
# 173      435.0  2.136283  runtime
# 174      440.0  1.904328    len_h
# 175      440.0  2.504315  runtime
# 176      445.0  2.131018    len_h
# 177      445.0  2.920112  runtime
#
# [178 rows x 3 columns]

# %%
sns.lineplot(data=frame, x='iteration', y='value', hue='type')
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='value'>

# %%
sns.lineplot(data=frame_norm, x='iteration', y='value', hue='type')
# Out:
# <AxesSubplot:xlabel='iteration', ylabel='value'>

# %% [markdown]
# # Format All Rules and save to file

# %%
models = ['roberta-base', 'roberta-large', 'bert-base-cased', 'bert-large-cased']
#eqs = [50, 100, 150]
eqs = [200]
experiments = range(1,11)
background = load_background()
lookup = get_lookup(binarizer)

# %%
for lm in models:
    for eq in eqs:
        all_negations = []
        all_implications = []
        for e in experiments:
            h = load_rules(lm, eq, e)
            all_rules = get_all_rules(h, background)
            (rules, negations, implications) = make_rule_lists(all_rules)
            all_negations = [*all_negations, *negations]
            all_implications = [*all_implications, *implications]

        relevant_implications = []
        for rule in all_implications:
            if rule['body'] not in all_negations:
                relevant_implications.append(rule)

        negations_count = count_lists(all_negations)
        implications_count = count_lists(relevant_implications)
        
        filename_latex = 'data/rule_extraction_final/formatted/' + lm + '_' + str(eq) +'_latex.txt'

        for rule, count in sorted(negations_count, key=lambda rule: rule[1], reverse=True):
            with open(filename_latex, 'a') as f:
                line = "${}\\ :\\  {rule}\\\\".format(count, rule=negation_to_latex(rule, lookup))
                f.write(line + '\n')

        for rule, count in sorted(implications_count, key=lambda rule: rule[1], reverse=True):
            with open(filename_latex, 'a') as f:
                line = "${}\\ :\\  {rule}\\\\".format(count, rule=implication_to_latex(rule, lookup))
                f.write(line + '\n')
